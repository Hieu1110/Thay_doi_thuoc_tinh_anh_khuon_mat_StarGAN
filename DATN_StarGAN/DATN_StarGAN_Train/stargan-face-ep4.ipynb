# %%
# Copy thư mục mô hình cũ sang /kaggle/working/
# !cp -r /kaggle/input/stargan-face-ep3/stargan /kaggle/working/

# %cd stargan
# Out:
# /kaggle/working/stargan

# %%
# !python main.py --mode train \
  --dataset CelebA \
  --image_size 156 \
  --c_dim 17 \
  --attr_path data/celeba/list_attr_celeba.txt \
  --celeba_image_dir /kaggle/input/celeba-dataset/img_align_celeba/img_align_celeba \
  --log_dir stargan_celeba/logs \
  --model_save_dir stargan_celeba/models \
  --result_dir stargan_celeba/results \
  --sample_dir stargan_celeba/samples \
  --batch_size 16 \
  --g_lr 0.00005 \
  --d_lr 0.00005 \
  --num_iters 650000 \
  --num_iters_decay 80000 \
  --resume_iters 500000 \
  --sample_step 20000 \
  --model_save_step 50000 \
  --log_step 2000 \
  --selected_attrs  Bald	Bangs		Black_Hair	Blond_Hair	Chubby	Eyeglasses	Goatee	Gray_Hair	Heavy_Makeup	Male	Mouth_Slightly_Open	Mustache	No_Beard	Pale_Skin		Rosy_Cheeks	Smiling	Wearing_Lipstick
# Out:
# Namespace(c_dim=17, c2_dim=8, celeba_crop_size=178, rafd_crop_size=256, image_size=156, g_conv_dim=64, d_conv_dim=64, g_repeat_num=6, d_repeat_num=6, lambda_cls=1, lambda_rec=10, lambda_gp=10, dataset='CelebA', batch_size=16, num_iters=650000, num_iters_decay=80000, g_lr=5e-05, d_lr=5e-05, n_critic=5, beta1=0.5, beta2=0.999, resume_iters=500000, selected_attrs=['Bald', 'Bangs', 'Black_Hair', 'Blond_Hair', 'Chubby', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'Male', 'Mouth_Slightly_Open', 'Mustache', 'No_Beard', 'Pale_Skin', 'Rosy_Cheeks', 'Smiling', 'Wearing_Lipstick'], test_iters=200000, num_workers=1, mode='train', use_tensorboard=True, celeba_image_dir='/kaggle/input/celeba-dataset/img_align_celeba/img_align_celeba', attr_path='data/celeba/list_attr_celeba.txt', rafd_image_dir='data/RaFD/train', log_dir='stargan_celeba/logs', model_save_dir='stargan_celeba/models', sample_dir='stargan_celeba/samples', result_dir='stargan_celeba/results', log_step=2000, sample_step=20000, model_save_step=50000, lr_update_step=1000)
# Finished preprocessing the CelebA dataset...
# Generator(
#   (main): Sequential(
#     (0): Conv2d(20, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (16): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (19): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (22): Tanh()
#   )
# )
# G
# The number of parameters: 8468160
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (conv1): Conv2d(2048, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv2): Conv2d(2048, 17, kernel_size=(2, 2), stride=(1, 1), bias=False)
# )
# D
# The number of parameters: 44860352
# 2025-11-30 01:36:54.865408: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764466615.082319      41 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764466615.148148      41 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# I0000 00:00:1764466631.153582      41 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15289 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Loading the trained models from step 500000...
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Elapsed [0:08:00], Iteration [502000/650000], D/loss_real: -2.6235, D/loss_fake: 0.7641, D/loss_cls: 0.6880, D/loss_gp: 0.0085, G/loss_fake: -0.6022, G/loss_rec: 0.0619, G/loss_cls: 0.5661
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Elapsed [0:15:41], Iteration [504000/650000], D/loss_real: -3.1455, D/loss_fake: 1.2515, D/loss_cls: 0.5261, D/loss_gp: 0.0175, G/loss_fake: -1.2789, G/loss_rec: 0.0616, G/loss_cls: 0.0942
# Elapsed [0:23:21], Iteration [506000/650000], D/loss_real: -3.0467, D/loss_fake: 1.6653, D/loss_cls: 0.3982, D/loss_gp: 0.0047, G/loss_fake: -1.6164, G/loss_rec: 0.0632, G/loss_cls: 0.8214
# Elapsed [0:31:01], Iteration [508000/650000], D/loss_real: -2.4559, D/loss_fake: 0.5555, D/loss_cls: 0.3778, D/loss_gp: 0.0101, G/loss_fake: -0.4582, G/loss_rec: 0.0651, G/loss_cls: 0.0616
# Elapsed [0:38:41], Iteration [510000/650000], D/loss_real: -1.7365, D/loss_fake: 0.2360, D/loss_cls: 0.5364, D/loss_gp: 0.0100, G/loss_fake: -0.0678, G/loss_rec: 0.0639, G/loss_cls: 0.7962
# Elapsed [0:46:21], Iteration [512000/650000], D/loss_real: -2.3022, D/loss_fake: 0.7162, D/loss_cls: 0.3505, D/loss_gp: 0.0052, G/loss_fake: -0.5912, G/loss_rec: 0.0554, G/loss_cls: 0.5889
# Elapsed [0:54:08], Iteration [514000/650000], D/loss_real: -3.0819, D/loss_fake: 1.1609, D/loss_cls: 0.4308, D/loss_gp: 0.0063, G/loss_fake: -0.9502, G/loss_rec: 0.0624, G/loss_cls: 1.4877
# Elapsed [1:01:48], Iteration [516000/650000], D/loss_real: -1.9957, D/loss_fake: 0.6263, D/loss_cls: 0.4805, D/loss_gp: 0.0060, G/loss_fake: -0.4139, G/loss_rec: 0.0648, G/loss_cls: 1.3232
# Elapsed [1:09:29], Iteration [518000/650000], D/loss_real: -2.4567, D/loss_fake: 1.1140, D/loss_cls: 0.3114, D/loss_gp: 0.0109, G/loss_fake: -0.7208, G/loss_rec: 0.0639, G/loss_cls: 0.7979
# Elapsed [1:17:09], Iteration [520000/650000], D/loss_real: -3.0222, D/loss_fake: 1.2554, D/loss_cls: 0.6311, D/loss_gp: 0.0116, G/loss_fake: -1.1673, G/loss_rec: 0.0618, G/loss_cls: 0.3670
# Saved real and fake images into stargan_celeba/samples/520000-images.jpg...
# Elapsed [1:24:51], Iteration [522000/650000], D/loss_real: -2.2017, D/loss_fake: 0.3040, D/loss_cls: 0.4045, D/loss_gp: 0.0116, G/loss_fake: -0.0596, G/loss_rec: 0.0618, G/loss_cls: 0.5383
# Elapsed [1:32:32], Iteration [524000/650000], D/loss_real: -3.3432, D/loss_fake: 1.3500, D/loss_cls: 1.0519, D/loss_gp: 0.0218, G/loss_fake: -1.2457, G/loss_rec: 0.0618, G/loss_cls: 0.3230
# Elapsed [1:40:17], Iteration [526000/650000], D/loss_real: -2.3535, D/loss_fake: 1.1498, D/loss_cls: 0.3407, D/loss_gp: 0.0072, G/loss_fake: -1.0364, G/loss_rec: 0.0581, G/loss_cls: 0.0952
# Elapsed [1:47:58], Iteration [528000/650000], D/loss_real: -2.0995, D/loss_fake: 0.5461, D/loss_cls: 0.2589, D/loss_gp: 0.0163, G/loss_fake: -0.5622, G/loss_rec: 0.0623, G/loss_cls: 0.2593
# Elapsed [1:55:38], Iteration [530000/650000], D/loss_real: -2.0995, D/loss_fake: 0.2437, D/loss_cls: 0.5400, D/loss_gp: 0.0175, G/loss_fake: -0.2032, G/loss_rec: 0.0551, G/loss_cls: 0.0276
# Elapsed [2:03:18], Iteration [532000/650000], D/loss_real: -3.1060, D/loss_fake: 1.4633, D/loss_cls: 0.4319, D/loss_gp: 0.0128, G/loss_fake: -1.4102, G/loss_rec: 0.0606, G/loss_cls: 0.2851
# Elapsed [2:10:59], Iteration [534000/650000], D/loss_real: -2.6447, D/loss_fake: 1.0262, D/loss_cls: 0.8499, D/loss_gp: 0.0155, G/loss_fake: -0.9798, G/loss_rec: 0.0644, G/loss_cls: 1.1359
# Elapsed [2:18:38], Iteration [536000/650000], D/loss_real: -3.2397, D/loss_fake: 1.5963, D/loss_cls: 0.3902, D/loss_gp: 0.0084, G/loss_fake: -1.4734, G/loss_rec: 0.0569, G/loss_cls: 0.7954
# Elapsed [2:26:18], Iteration [538000/650000], D/loss_real: -3.6637, D/loss_fake: 1.5063, D/loss_cls: 0.4205, D/loss_gp: 0.0123, G/loss_fake: -1.3168, G/loss_rec: 0.0702, G/loss_cls: 0.3753
# Elapsed [2:33:57], Iteration [540000/650000], D/loss_real: -3.1941, D/loss_fake: 1.3903, D/loss_cls: 0.5195, D/loss_gp: 0.0119, G/loss_fake: -1.3092, G/loss_rec: 0.0654, G/loss_cls: 0.1947
# Saved real and fake images into stargan_celeba/samples/540000-images.jpg...
# Elapsed [2:41:37], Iteration [542000/650000], D/loss_real: -2.5810, D/loss_fake: 1.0223, D/loss_cls: 0.4772, D/loss_gp: 0.0094, G/loss_fake: -1.0420, G/loss_rec: 0.0591, G/loss_cls: 0.2738
# Elapsed [2:49:16], Iteration [544000/650000], D/loss_real: -1.7279, D/loss_fake: -0.0720, D/loss_cls: 0.7955, D/loss_gp: 0.0062, G/loss_fake: 0.2630, G/loss_rec: 0.0624, G/loss_cls: 0.4682
# Elapsed [2:56:55], Iteration [546000/650000], D/loss_real: -2.6659, D/loss_fake: 1.0024, D/loss_cls: 0.2326, D/loss_gp: 0.0086, G/loss_fake: -0.8472, G/loss_rec: 0.0597, G/loss_cls: 0.4998
# Elapsed [3:04:34], Iteration [548000/650000], D/loss_real: -3.5782, D/loss_fake: 1.7241, D/loss_cls: 0.7295, D/loss_gp: 0.0109, G/loss_fake: -1.9202, G/loss_rec: 0.0658, G/loss_cls: 0.9848
# Elapsed [3:12:13], Iteration [550000/650000], D/loss_real: -2.2379, D/loss_fake: 0.5527, D/loss_cls: 1.0348, D/loss_gp: 0.0127, G/loss_fake: -0.3874, G/loss_rec: 0.0571, G/loss_cls: 1.4904
# Saved model checkpoints into stargan_celeba/models...
# Elapsed [3:19:53], Iteration [552000/650000], D/loss_real: -3.0257, D/loss_fake: 1.2608, D/loss_cls: 0.7045, D/loss_gp: 0.0092, G/loss_fake: -1.4388, G/loss_rec: 0.0644, G/loss_cls: 0.1841
# Elapsed [3:27:32], Iteration [554000/650000], D/loss_real: -2.8771, D/loss_fake: 0.9777, D/loss_cls: 0.5146, D/loss_gp: 0.0140, G/loss_fake: -0.9099, G/loss_rec: 0.0602, G/loss_cls: 0.0446
# Elapsed [3:35:11], Iteration [556000/650000], D/loss_real: -3.5517, D/loss_fake: 1.5345, D/loss_cls: 0.5919, D/loss_gp: 0.0100, G/loss_fake: -1.4087, G/loss_rec: 0.0612, G/loss_cls: 1.3368
# Elapsed [3:42:50], Iteration [558000/650000], D/loss_real: -1.4169, D/loss_fake: -0.5784, D/loss_cls: 0.2701, D/loss_gp: 0.0166, G/loss_fake: 0.5413, G/loss_rec: 0.0653, G/loss_cls: 0.1522
# Elapsed [3:50:29], Iteration [560000/650000], D/loss_real: -2.3727, D/loss_fake: 0.5874, D/loss_cls: 0.2211, D/loss_gp: 0.0108, G/loss_fake: -0.5634, G/loss_rec: 0.0630, G/loss_cls: 0.3847
# Saved real and fake images into stargan_celeba/samples/560000-images.jpg...
# Elapsed [3:58:09], Iteration [562000/650000], D/loss_real: -2.2472, D/loss_fake: 0.9524, D/loss_cls: 0.3220, D/loss_gp: 0.0047, G/loss_fake: -0.9540, G/loss_rec: 0.0571, G/loss_cls: 0.6225
# Elapsed [4:05:49], Iteration [564000/650000], D/loss_real: -3.5977, D/loss_fake: 0.9232, D/loss_cls: 0.5376, D/loss_gp: 0.0219, G/loss_fake: -0.8326, G/loss_rec: 0.0610, G/loss_cls: 0.3627
# Elapsed [4:13:28], Iteration [566000/650000], D/loss_real: -2.4194, D/loss_fake: 0.7707, D/loss_cls: 0.2204, D/loss_gp: 0.0095, G/loss_fake: -0.7381, G/loss_rec: 0.0565, G/loss_cls: 0.1447
# Elapsed [4:21:08], Iteration [568000/650000], D/loss_real: -1.9096, D/loss_fake: 0.3235, D/loss_cls: 0.4404, D/loss_gp: 0.0117, G/loss_fake: -0.2629, G/loss_rec: 0.0672, G/loss_cls: 0.4556
# Elapsed [4:28:48], Iteration [570000/650000], D/loss_real: -2.3831, D/loss_fake: 1.0586, D/loss_cls: 0.4130, D/loss_gp: 0.0103, G/loss_fake: -0.9190, G/loss_rec: 0.0572, G/loss_cls: 0.0378
# Decayed learning rates, g_lr: 4.9999375e-05, d_lr: 4.9999375e-05.
# Elapsed [4:36:28], Iteration [572000/650000], D/loss_real: -2.3414, D/loss_fake: 0.7784, D/loss_cls: 0.6774, D/loss_gp: 0.0070, G/loss_fake: -0.5593, G/loss_rec: 0.0659, G/loss_cls: 0.2697
# Decayed learning rates, g_lr: 4.9998749999999996e-05, d_lr: 4.9998749999999996e-05.
# Decayed learning rates, g_lr: 4.999812499999999e-05, d_lr: 4.999812499999999e-05.
# Elapsed [4:44:06], Iteration [574000/650000], D/loss_real: -2.5371, D/loss_fake: 1.0760, D/loss_cls: 0.1545, D/loss_gp: 0.0090, G/loss_fake: -0.7951, G/loss_rec: 0.0622, G/loss_cls: 0.3729
# Decayed learning rates, g_lr: 4.999749999999999e-05, d_lr: 4.999749999999999e-05.
# Decayed learning rates, g_lr: 4.999687499999999e-05, d_lr: 4.999687499999999e-05.
# Elapsed [4:51:46], Iteration [576000/650000], D/loss_real: -3.5217, D/loss_fake: 1.6555, D/loss_cls: 0.7258, D/loss_gp: 0.0079, G/loss_fake: -1.7663, G/loss_rec: 0.0621, G/loss_cls: 0.4877
# Decayed learning rates, g_lr: 4.9996249999999984e-05, d_lr: 4.9996249999999984e-05.
# Decayed learning rates, g_lr: 4.999562499999998e-05, d_lr: 4.999562499999998e-05.
# Elapsed [4:59:25], Iteration [578000/650000], D/loss_real: -2.8768, D/loss_fake: 1.0557, D/loss_cls: 0.2659, D/loss_gp: 0.0077, G/loss_fake: -1.1079, G/loss_rec: 0.0611, G/loss_cls: 0.2558
# Decayed learning rates, g_lr: 4.999499999999998e-05, d_lr: 4.999499999999998e-05.
# Decayed learning rates, g_lr: 4.9994374999999975e-05, d_lr: 4.9994374999999975e-05.
# Elapsed [5:07:04], Iteration [580000/650000], D/loss_real: -2.7250, D/loss_fake: 1.2937, D/loss_cls: 0.2832, D/loss_gp: 0.0052, G/loss_fake: -1.2137, G/loss_rec: 0.0686, G/loss_cls: 0.5657
# Saved real and fake images into stargan_celeba/samples/580000-images.jpg...
# Decayed learning rates, g_lr: 4.999374999999997e-05, d_lr: 4.999374999999997e-05.
# Decayed learning rates, g_lr: 4.999312499999997e-05, d_lr: 4.999312499999997e-05.
# Elapsed [5:14:44], Iteration [582000/650000], D/loss_real: -2.5288, D/loss_fake: 0.5152, D/loss_cls: 0.3430, D/loss_gp: 0.0139, G/loss_fake: -0.4271, G/loss_rec: 0.0602, G/loss_cls: 0.3279
# Decayed learning rates, g_lr: 4.9992499999999966e-05, d_lr: 4.9992499999999966e-05.
# Decayed learning rates, g_lr: 4.999187499999996e-05, d_lr: 4.999187499999996e-05.
# Elapsed [5:22:23], Iteration [584000/650000], D/loss_real: -3.6474, D/loss_fake: 1.8974, D/loss_cls: 0.6768, D/loss_gp: 0.0222, G/loss_fake: -1.9573, G/loss_rec: 0.0615, G/loss_cls: 0.1675
# Decayed learning rates, g_lr: 4.999124999999996e-05, d_lr: 4.999124999999996e-05.
# Decayed learning rates, g_lr: 4.9990624999999956e-05, d_lr: 4.9990624999999956e-05.
# Elapsed [5:30:03], Iteration [586000/650000], D/loss_real: -2.5608, D/loss_fake: 0.7449, D/loss_cls: 0.2524, D/loss_gp: 0.0081, G/loss_fake: -0.7249, G/loss_rec: 0.0602, G/loss_cls: 0.2149
# Decayed learning rates, g_lr: 4.998999999999995e-05, d_lr: 4.998999999999995e-05.
# Decayed learning rates, g_lr: 4.998937499999995e-05, d_lr: 4.998937499999995e-05.
# Elapsed [5:37:42], Iteration [588000/650000], D/loss_real: -2.5985, D/loss_fake: 1.2580, D/loss_cls: 0.3639, D/loss_gp: 0.0094, G/loss_fake: -1.3856, G/loss_rec: 0.0620, G/loss_cls: 0.3770
# Decayed learning rates, g_lr: 4.998874999999995e-05, d_lr: 4.998874999999995e-05.
# Decayed learning rates, g_lr: 4.9988124999999944e-05, d_lr: 4.9988124999999944e-05.
# Elapsed [5:45:22], Iteration [590000/650000], D/loss_real: -2.2303, D/loss_fake: 0.9151, D/loss_cls: 0.6792, D/loss_gp: 0.0087, G/loss_fake: -0.7092, G/loss_rec: 0.0619, G/loss_cls: 0.3542
# Decayed learning rates, g_lr: 4.998749999999994e-05, d_lr: 4.998749999999994e-05.
# Decayed learning rates, g_lr: 4.998687499999994e-05, d_lr: 4.998687499999994e-05.
# Elapsed [5:53:01], Iteration [592000/650000], D/loss_real: -2.1546, D/loss_fake: 0.5834, D/loss_cls: 0.2215, D/loss_gp: 0.0089, G/loss_fake: -0.4155, G/loss_rec: 0.0625, G/loss_cls: 0.7362
# Decayed learning rates, g_lr: 4.9986249999999935e-05, d_lr: 4.9986249999999935e-05.
# Decayed learning rates, g_lr: 4.998562499999993e-05, d_lr: 4.998562499999993e-05.
# Elapsed [6:00:40], Iteration [594000/650000], D/loss_real: -1.9840, D/loss_fake: 0.6532, D/loss_cls: 0.3911, D/loss_gp: 0.0062, G/loss_fake: -0.5384, G/loss_rec: 0.0633, G/loss_cls: 0.4630
# Decayed learning rates, g_lr: 4.998499999999993e-05, d_lr: 4.998499999999993e-05.
# Decayed learning rates, g_lr: 4.9984374999999926e-05, d_lr: 4.9984374999999926e-05.
# Elapsed [6:08:20], Iteration [596000/650000], D/loss_real: -1.9728, D/loss_fake: 0.0280, D/loss_cls: 0.2520, D/loss_gp: 0.0121, G/loss_fake: -0.0271, G/loss_rec: 0.0602, G/loss_cls: 0.2734
# Decayed learning rates, g_lr: 4.998374999999992e-05, d_lr: 4.998374999999992e-05.
# Decayed learning rates, g_lr: 4.998312499999992e-05, d_lr: 4.998312499999992e-05.
# Elapsed [6:15:59], Iteration [598000/650000], D/loss_real: -1.9478, D/loss_fake: 0.4544, D/loss_cls: 0.2557, D/loss_gp: 0.0057, G/loss_fake: -0.3281, G/loss_rec: 0.0565, G/loss_cls: 0.1314
# Decayed learning rates, g_lr: 4.9982499999999917e-05, d_lr: 4.9982499999999917e-05.
# Decayed learning rates, g_lr: 4.9981874999999914e-05, d_lr: 4.9981874999999914e-05.
# Elapsed [6:23:39], Iteration [600000/650000], D/loss_real: -1.9212, D/loss_fake: 0.2505, D/loss_cls: 0.9142, D/loss_gp: 0.0063, G/loss_fake: 0.0720, G/loss_rec: 0.0631, G/loss_cls: 0.3669
# Saved real and fake images into stargan_celeba/samples/600000-images.jpg...
# Saved model checkpoints into stargan_celeba/models...
# Decayed learning rates, g_lr: 4.998124999999991e-05, d_lr: 4.998124999999991e-05.
# Decayed learning rates, g_lr: 4.998062499999991e-05, d_lr: 4.998062499999991e-05.
# Elapsed [6:31:20], Iteration [602000/650000], D/loss_real: -2.5854, D/loss_fake: 0.5880, D/loss_cls: 0.4245, D/loss_gp: 0.0064, G/loss_fake: -0.2049, G/loss_rec: 0.0650, G/loss_cls: 0.4092
# Decayed learning rates, g_lr: 4.9979999999999904e-05, d_lr: 4.9979999999999904e-05.
# Decayed learning rates, g_lr: 4.99793749999999e-05, d_lr: 4.99793749999999e-05.
# Elapsed [6:38:59], Iteration [604000/650000], D/loss_real: -1.7773, D/loss_fake: -0.4735, D/loss_cls: 0.3385, D/loss_gp: 0.0164, G/loss_fake: 0.4240, G/loss_rec: 0.0652, G/loss_cls: 0.2282
# Decayed learning rates, g_lr: 4.99787499999999e-05, d_lr: 4.99787499999999e-05.
# Decayed learning rates, g_lr: 4.9978124999999895e-05, d_lr: 4.9978124999999895e-05.
# Elapsed [6:46:38], Iteration [606000/650000], D/loss_real: -3.5547, D/loss_fake: 1.3015, D/loss_cls: 0.8670, D/loss_gp: 0.0169, G/loss_fake: -1.2915, G/loss_rec: 0.0675, G/loss_cls: 0.7446
# Decayed learning rates, g_lr: 4.997749999999989e-05, d_lr: 4.997749999999989e-05.
# Decayed learning rates, g_lr: 4.997687499999989e-05, d_lr: 4.997687499999989e-05.
# Elapsed [6:54:17], Iteration [608000/650000], D/loss_real: -2.8409, D/loss_fake: 1.2950, D/loss_cls: 0.5034, D/loss_gp: 0.0082, G/loss_fake: -1.0682, G/loss_rec: 0.0557, G/loss_cls: 0.4003
# Decayed learning rates, g_lr: 4.9976249999999886e-05, d_lr: 4.9976249999999886e-05.
# Decayed learning rates, g_lr: 4.997562499999988e-05, d_lr: 4.997562499999988e-05.
# Elapsed [7:01:57], Iteration [610000/650000], D/loss_real: -3.1774, D/loss_fake: 1.7455, D/loss_cls: 0.3225, D/loss_gp: 0.0080, G/loss_fake: -1.4085, G/loss_rec: 0.0568, G/loss_cls: 1.0986
# Decayed learning rates, g_lr: 4.997499999999988e-05, d_lr: 4.997499999999988e-05.
# Decayed learning rates, g_lr: 4.997437499999988e-05, d_lr: 4.997437499999988e-05.
# Elapsed [7:09:36], Iteration [612000/650000], D/loss_real: -2.4246, D/loss_fake: 0.3486, D/loss_cls: 0.7556, D/loss_gp: 0.0190, G/loss_fake: -0.4042, G/loss_rec: 0.0673, G/loss_cls: 0.5367
# Decayed learning rates, g_lr: 4.9973749999999874e-05, d_lr: 4.9973749999999874e-05.
# Decayed learning rates, g_lr: 4.997312499999987e-05, d_lr: 4.997312499999987e-05.
# Elapsed [7:17:16], Iteration [614000/650000], D/loss_real: -2.8103, D/loss_fake: 1.0000, D/loss_cls: 0.1357, D/loss_gp: 0.0105, G/loss_fake: -0.9234, G/loss_rec: 0.0572, G/loss_cls: 0.0193
# Decayed learning rates, g_lr: 4.997249999999987e-05, d_lr: 4.997249999999987e-05.
# Decayed learning rates, g_lr: 4.9971874999999864e-05, d_lr: 4.9971874999999864e-05.
# Elapsed [7:24:55], Iteration [616000/650000], D/loss_real: -2.2534, D/loss_fake: 0.4031, D/loss_cls: 0.1253, D/loss_gp: 0.0105, G/loss_fake: -0.3220, G/loss_rec: 0.0605, G/loss_cls: 0.0329
# Decayed learning rates, g_lr: 4.997124999999986e-05, d_lr: 4.997124999999986e-05.
# Decayed learning rates, g_lr: 4.997062499999986e-05, d_lr: 4.997062499999986e-05.
# Elapsed [7:32:34], Iteration [618000/650000], D/loss_real: -2.3779, D/loss_fake: 0.6632, D/loss_cls: 0.2227, D/loss_gp: 0.0095, G/loss_fake: -0.7002, G/loss_rec: 0.0582, G/loss_cls: 0.1541
# Decayed learning rates, g_lr: 4.9969999999999855e-05, d_lr: 4.9969999999999855e-05.
# Decayed learning rates, g_lr: 4.996937499999985e-05, d_lr: 4.996937499999985e-05.
# Elapsed [7:40:14], Iteration [620000/650000], D/loss_real: -2.1497, D/loss_fake: 0.5703, D/loss_cls: 0.1926, D/loss_gp: 0.0105, G/loss_fake: -0.3564, G/loss_rec: 0.0593, G/loss_cls: 0.1615
# Saved real and fake images into stargan_celeba/samples/620000-images.jpg...
# Decayed learning rates, g_lr: 4.996874999999985e-05, d_lr: 4.996874999999985e-05.
# Decayed learning rates, g_lr: 4.9968124999999846e-05, d_lr: 4.9968124999999846e-05.
# Elapsed [7:47:54], Iteration [622000/650000], D/loss_real: -2.0542, D/loss_fake: -0.0484, D/loss_cls: 0.4858, D/loss_gp: 0.0071, G/loss_fake: 0.4231, G/loss_rec: 0.0603, G/loss_cls: 0.1379
# Decayed learning rates, g_lr: 4.996749999999984e-05, d_lr: 4.996749999999984e-05.
# Decayed learning rates, g_lr: 4.996687499999984e-05, d_lr: 4.996687499999984e-05.
# Elapsed [7:55:34], Iteration [624000/650000], D/loss_real: -2.0861, D/loss_fake: 0.3203, D/loss_cls: 0.5141, D/loss_gp: 0.0063, G/loss_fake: -0.2238, G/loss_rec: 0.0583, G/loss_cls: 0.6703
# Decayed learning rates, g_lr: 4.996624999999984e-05, d_lr: 4.996624999999984e-05.
# Decayed learning rates, g_lr: 4.9965624999999834e-05, d_lr: 4.9965624999999834e-05.
# Elapsed [8:03:13], Iteration [626000/650000], D/loss_real: -3.2431, D/loss_fake: 0.6130, D/loss_cls: 0.1227, D/loss_gp: 0.0140, G/loss_fake: -0.3848, G/loss_rec: 0.0689, G/loss_cls: 1.0901
# Decayed learning rates, g_lr: 4.996499999999983e-05, d_lr: 4.996499999999983e-05.
# Decayed learning rates, g_lr: 4.996437499999983e-05, d_lr: 4.996437499999983e-05.
# Elapsed [8:10:53], Iteration [628000/650000], D/loss_real: -3.6431, D/loss_fake: 2.1943, D/loss_cls: 0.2473, D/loss_gp: 0.0091, G/loss_fake: -1.9098, G/loss_rec: 0.0573, G/loss_cls: 0.2575
# Decayed learning rates, g_lr: 4.9963749999999825e-05, d_lr: 4.9963749999999825e-05.
# Decayed learning rates, g_lr: 4.996312499999982e-05, d_lr: 4.996312499999982e-05.
# Elapsed [8:18:32], Iteration [630000/650000], D/loss_real: -3.0447, D/loss_fake: 0.8644, D/loss_cls: 0.3279, D/loss_gp: 0.0085, G/loss_fake: -0.7765, G/loss_rec: 0.0557, G/loss_cls: 0.2317
# Decayed learning rates, g_lr: 4.996249999999982e-05, d_lr: 4.996249999999982e-05.
# Decayed learning rates, g_lr: 4.9961874999999815e-05, d_lr: 4.9961874999999815e-05.
# Elapsed [8:26:12], Iteration [632000/650000], D/loss_real: -3.6801, D/loss_fake: 1.8746, D/loss_cls: 0.4042, D/loss_gp: 0.0155, G/loss_fake: -1.3399, G/loss_rec: 0.0609, G/loss_cls: 0.0238
# Decayed learning rates, g_lr: 4.996124999999981e-05, d_lr: 4.996124999999981e-05.
# Decayed learning rates, g_lr: 4.996062499999981e-05, d_lr: 4.996062499999981e-05.
# Elapsed [8:33:51], Iteration [634000/650000], D/loss_real: -1.1813, D/loss_fake: -0.6273, D/loss_cls: 0.3783, D/loss_gp: 0.0188, G/loss_fake: 0.5504, G/loss_rec: 0.0562, G/loss_cls: 0.0162
# Decayed learning rates, g_lr: 4.9959999999999806e-05, d_lr: 4.9959999999999806e-05.
# Decayed learning rates, g_lr: 4.99593749999998e-05, d_lr: 4.99593749999998e-05.
# Elapsed [8:41:31], Iteration [636000/650000], D/loss_real: -2.0628, D/loss_fake: 0.3302, D/loss_cls: 0.3229, D/loss_gp: 0.0068, G/loss_fake: -0.3595, G/loss_rec: 0.0533, G/loss_cls: 0.0845
# Decayed learning rates, g_lr: 4.99587499999998e-05, d_lr: 4.99587499999998e-05.
# Decayed learning rates, g_lr: 4.99581249999998e-05, d_lr: 4.99581249999998e-05.
# Elapsed [8:49:10], Iteration [638000/650000], D/loss_real: -2.9956, D/loss_fake: 1.3224, D/loss_cls: 0.1508, D/loss_gp: 0.0163, G/loss_fake: -1.3734, G/loss_rec: 0.0644, G/loss_cls: 0.1765
# Decayed learning rates, g_lr: 4.9957499999999794e-05, d_lr: 4.9957499999999794e-05.
# Decayed learning rates, g_lr: 4.995687499999979e-05, d_lr: 4.995687499999979e-05.
# Elapsed [8:56:50], Iteration [640000/650000], D/loss_real: -2.8910, D/loss_fake: 0.6630, D/loss_cls: 0.1694, D/loss_gp: 0.0071, G/loss_fake: -0.6112, G/loss_rec: 0.0613, G/loss_cls: 0.0166
# Saved real and fake images into stargan_celeba/samples/640000-images.jpg...
# Decayed learning rates, g_lr: 4.995624999999979e-05, d_lr: 4.995624999999979e-05.
# Decayed learning rates, g_lr: 4.9955624999999785e-05, d_lr: 4.9955624999999785e-05.
# Elapsed [9:04:30], Iteration [642000/650000], D/loss_real: -2.5093, D/loss_fake: 0.6606, D/loss_cls: 0.5089, D/loss_gp: 0.0136, G/loss_fake: -0.5828, G/loss_rec: 0.0715, G/loss_cls: 0.0430
# Decayed learning rates, g_lr: 4.995499999999978e-05, d_lr: 4.995499999999978e-05.
# Decayed learning rates, g_lr: 4.995437499999978e-05, d_lr: 4.995437499999978e-05.
# Elapsed [9:12:09], Iteration [644000/650000], D/loss_real: -2.6099, D/loss_fake: 0.6545, D/loss_cls: 0.2417, D/loss_gp: 0.0063, G/loss_fake: -0.4795, G/loss_rec: 0.0607, G/loss_cls: 0.1360
# Decayed learning rates, g_lr: 4.9953749999999776e-05, d_lr: 4.9953749999999776e-05.
# Decayed learning rates, g_lr: 4.995312499999977e-05, d_lr: 4.995312499999977e-05.
# Elapsed [9:19:48], Iteration [646000/650000], D/loss_real: -4.0516, D/loss_fake: 2.2277, D/loss_cls: 0.4262, D/loss_gp: 0.0107, G/loss_fake: -2.0369, G/loss_rec: 0.0569, G/loss_cls: 1.4264
# Decayed learning rates, g_lr: 4.995249999999977e-05, d_lr: 4.995249999999977e-05.
# Decayed learning rates, g_lr: 4.9951874999999766e-05, d_lr: 4.9951874999999766e-05.
# Elapsed [9:27:27], Iteration [648000/650000], D/loss_real: -3.3327, D/loss_fake: 1.2446, D/loss_cls: 0.4092, D/loss_gp: 0.0081, G/loss_fake: -1.0822, G/loss_rec: 0.0645, G/loss_cls: 0.5357
# Decayed learning rates, g_lr: 4.995124999999976e-05, d_lr: 4.995124999999976e-05.
# Decayed learning rates, g_lr: 4.995062499999976e-05, d_lr: 4.995062499999976e-05.
# Elapsed [9:35:05], Iteration [650000/650000], D/loss_real: -2.1095, D/loss_fake: 0.8316, D/loss_cls: 0.2396, D/loss_gp: 0.0130, G/loss_fake: -0.6153, G/loss_rec: 0.0614, G/loss_cls: 0.3049
# Saved model checkpoints into stargan_celeba/models...
# Decayed learning rates, g_lr: 4.994999999999976e-05, d_lr: 4.994999999999976e-05.
