# %%
# !cp -r /kaggle/input/evaluate-stargan-graph/* /kaggle/working/

# %%
import os, random, shutil
from pathlib import Path

# --- các đường dẫn (chỉnh nếu khác) ---
WORK_STARGAN = "/kaggle/working/stargan"
SOURCE_IMG_DIR = "/kaggle/input/celeba-dataset/img_align_celeba/img_align_celeba"
DEST_IMG_DIR = os.path.join(WORK_STARGAN, "data/celeba/img")
ATTR_SRC = "/kaggle/input/celeba-dataset/list_attr_celeba.txt"  # original attr file in input
ATTR_DEST = os.path.join(WORK_STARGAN, "data/celeba/list_attr_celeba.txt")
ATTR_SMALL = os.path.join(WORK_STARGAN, "data/celeba/1k_attr_face.txt")
NUM_SELECT = 1000

# %%
import os, cv2, shutil, numpy as np, torch
from skimage.metrics import structural_similarity as ssim
from torchvision import transforms
from torchvision.models import inception_v3
from torchvision.models.feature_extraction import create_feature_extractor
from concurrent.futures import ProcessPoolExecutor
from PIL import Image
from scipy.linalg import sqrtm

# ============================================================
# CONFIG
# ============================================================
PARTS = 18              # 1 real + 17 fake
PART_W, PART_H = 156, 156
NUM_CRITERIA = 17
INCEPTION_ON_CPU = True

device = 'cuda' if (torch.cuda.is_available() and not INCEPTION_ON_CPU) else 'cpu'

# ============================================================
# LOAD INCEPTION (fixed)
# ============================================================
from torchvision.models import Inception_V3_Weights
weights = Inception_V3_Weights.IMAGENET1K_V1

# KHÔNG truyền aux_logits nữa
inc = inception_v3(weights=weights).to(device).eval()

feat_extractor = create_feature_extractor(inc, return_nodes={'avgpool': 'feat'})

transform_incep = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# ============================================================
# IMAGE SPLIT
# ============================================================
def split_image_horizontally(image):
    parts = []
    for i in range(PARTS):
        x = i * PART_W
        crop = image[0:PART_H, x:x + PART_W]
        parts.append(crop.copy())
    return parts

def save_real_and_fakes_from_montage(montage_path, out_dir):
    img = cv2.imread(montage_path)
    if img is None:
        return None, []

    parts = split_image_horizontally(img)
    fname = os.path.basename(montage_path)

    real_dir = os.path.join(out_dir, "real")
    os.makedirs(real_dir, exist_ok=True)

    real_path = os.path.join(real_dir, f"real_{fname}")
    cv2.imwrite(real_path, parts[0])

    fake_paths = []
    for i, p in enumerate(parts[1:], start=1):
        fakedir = os.path.join(out_dir, "fake", str(i))
        os.makedirs(fakedir, exist_ok=True)
        fp = os.path.join(fakedir, f"fake_{fname}")
        cv2.imwrite(fp, p)
        fake_paths.append(fp)

    return real_path, fake_paths

# ============================================================
# SSIM
# ============================================================
def compute_ssim_pair(real_path, fake_path):
    a = cv2.imread(real_path)
    b = cv2.imread(fake_path)
    if a is None or b is None:
        return float('nan')

    if a.shape != b.shape:
        b = cv2.resize(b, (a.shape[1], a.shape[0]))

    try:
        return ssim(a, b, channel_axis=-1, win_size=3)
    except:
        return float('nan')

# ============================================================
# FID
# ============================================================
def extract_inception_feature(path):
    img = Image.open(path).convert('RGB')
    transform = transforms.Compose([
        transforms.Resize(299),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )
    ])
    x = transform(img).unsqueeze(0).to(device)

    with torch.no_grad():
        feat = inc(x)  # dùng model inception_v3 gốc
        feat = feat.squeeze().cpu().numpy()

    return feat

def calculate_fid(real_features, fake_features):
    mu_real = real_features.mean(axis=0)
    mu_fake = fake_features.mean(axis=0)

    sigma_real = np.cov(real_features, rowvar=False)
    sigma_fake = np.cov(fake_features, rowvar=False)

    diff = mu_real - mu_fake

    # matrix square root
    covmean = sqrtm(sigma_real @ sigma_fake)
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    fid = diff @ diff + np.trace(sigma_real + sigma_fake - 2 * covmean)
    return float(fid)


# ============================================================
# FULL EVALUATION
# ============================================================
def evaluate_results_folder(result_dir, max_workers=8):

    # 1. xóa real/fake cũ
    for sub in ["real", "fake"]:
        p = os.path.join(result_dir, sub)
        if os.path.exists(p):
            shutil.rmtree(p)
    os.makedirs(result_dir, exist_ok=True)

    # 2. tách montage
    montage_files = sorted(
        [os.path.join(result_dir, f) for f in os.listdir(result_dir) if f.lower().endswith(".jpg")]
    )

    for m in montage_files:
        save_real_and_fakes_from_montage(m, result_dir)

    # 3. load danh sách real
    real_dir = os.path.join(result_dir, "real")
    real_files = sorted(os.listdir(real_dir))
    real_paths = [os.path.join(real_dir, f) for f in real_files]

    # 4. SSIM
    ssim_avgs = []
    with ProcessPoolExecutor(max_workers=max_workers) as ex:
        for i in range(1, NUM_CRITERIA + 1):
            fake_dir = os.path.join(result_dir, "fake", str(i))
            if not os.path.exists(fake_dir):
                ssim_avgs.append(float('nan'))
                continue

            fake_files = sorted(os.listdir(fake_dir))
            fake_paths = [os.path.join(fake_dir, f) for f in fake_files]

            n = min(len(real_paths), len(fake_paths))
            jobs = [ex.submit(compute_ssim_pair, real_paths[k], fake_paths[k]) for k in range(n)]
            vals = [j.result() for j in jobs]
            ssim_avgs.append(float(np.nanmean(vals)))

    # 5. FID
    fid_scores = []
    for i in range(1, NUM_CRITERIA + 1):
        fake_dir = os.path.join(result_dir, "fake", str(i))

        if not os.path.exists(fake_dir):
            fid_scores.append(float('nan'))
            continue

        fake_files = sorted(os.listdir(fake_dir))
        fake_paths = [os.path.join(fake_dir, f) for f in fake_files]

        n = min(len(real_paths), len(fake_paths))
        real_feats = np.array([extract_inception_feature(real_paths[k]) for k in range(n)])
        fake_feats = np.array([extract_inception_feature(fake_paths[k]) for k in range(n)])
        
        fid_scores.append(calculate_fid(real_feats, fake_feats))

    return (
        float(np.nanmean(ssim_avgs)),
        ssim_avgs,
        float(np.nanmean([x for x in fid_scores if not np.isnan(x)])),
        fid_scores
    )
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 153MB/s]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/feature_extraction.py:175: UserWarning: NOTE: The nodes obtained by tracing the model in eval mode are a subsequence of those obtained in train mode. When choosing nodes for feature extraction, you may need to specify output nodes for train and eval mode separately.
#   warnings.warn(msg + suggestion_msg)

# %%
import subprocess, time, pandas as pd, shutil

CHECKPOINTS = [100000, 150000, 200000]
RESULT_DIR = "/kaggle/working/stargan/stargan_celeba/results"
MODEL_SAVE_DIR = "/kaggle/working/stargan/stargan_celeba/models"
ATTR_PATH = os.path.join(WORK_STARGAN, "data/celeba/1k_attr_face.txt")
CELEBA_IMG_DIR = os.path.join(WORK_STARGAN, "data/celeba/img")

master_results = []

criteria_names = [
    "Hói Đầu", "Tóc Mái", "Tóc Đen", "Tóc Vàng", "Mũm Mĩm", "Đeo Kính",
    "Râu Dê", "Tóc Bạc", "Trang Điểm Đậm", "Nam Giới", "Miệng Hơi Mở",
    "Râu Mép", "Không Râu", "Da Nhợt Nhạt", "Má Hồng", "Mỉm Cười", "Đánh Son"
]

for ckpt in CHECKPOINTS:
    print("\n" + "="*60)
    print(f"Testing checkpoint {ckpt}")

    if os.path.exists(RESULT_DIR):
        shutil.rmtree(RESULT_DIR)
    os.makedirs(RESULT_DIR, exist_ok=True)

    cmd = [
        "python", os.path.join(WORK_STARGAN, "main.py"),
        "--mode", "test",
        "--dataset", "CelebA",
        "--image_size", "156",
        "--c_dim", "17",
        "--selected_attrs",
        "Bald", "Bangs", "Black_Hair", "Blond_Hair", "Chubby", "Eyeglasses",
        "Goatee", "Gray_Hair", "Heavy_Makeup", "Male", "Mouth_Slightly_Open",
        "Mustache", "No_Beard", "Pale_Skin", "Rosy_Cheeks", "Smiling", "Wearing_Lipstick",
        f"--model_save_dir={MODEL_SAVE_DIR}",
        f"--result_dir={RESULT_DIR}",
        f"--attr_path={ATTR_PATH}",
        f"--celeba_image_dir={CELEBA_IMG_DIR}",
        f"--test_iters={ckpt}",
        "--batch_size=1"
    ]

    print("Running:", " ".join(cmd))
    t0 = time.time()
    subprocess.run(cmd, check=True)
    print(f"Test done in {time.time()-t0:.1f}s")

    # evaluate
    print("Evaluating SSIM/FID ...")
    t0 = time.time()
    mean_ssim, ssim_attr, mean_fid, fid_attr = evaluate_results_folder(RESULT_DIR, max_workers=8)
    print(f"Eval done in {time.time()-t0:.1f}s | SSIM={mean_ssim:.4f} | FID={mean_fid:.2f}")

    record = {
        "checkpoint": ckpt,
        "mean_ssim": mean_ssim,
        "mean_fid": mean_fid
    }

    for i, name in enumerate(criteria_names):
        record[f"ssim_{i+1}"] = float(ssim_attr[i])
        record[f"fid_{i+1}"] = float(fid_attr[i])

    master_results.append(record)

    df = pd.DataFrame(master_results)
    df.to_csv("/kaggle/working/stargan_eval_results_master.csv", index=False)
    print("Saved to /kaggle/working/stargan_eval_results_master.csv")
# Out:
# ============================================================
# Testing checkpoint 100000
# Running: python /kaggle/working/stargan/main.py --mode test --dataset CelebA --image_size 156 --c_dim 17 --selected_attrs Bald Bangs Black_Hair Blond_Hair Chubby Eyeglasses Goatee Gray_Hair Heavy_Makeup Male Mouth_Slightly_Open Mustache No_Beard Pale_Skin Rosy_Cheeks Smiling Wearing_Lipstick --model_save_dir=/kaggle/working/stargan/stargan_celeba/models --result_dir=/kaggle/working/stargan/stargan_celeba/results --attr_path=/kaggle/working/stargan/data/celeba/1k_attr_face.txt --celeba_image_dir=/kaggle/working/stargan/data/celeba/img --test_iters=100000 --batch_size=1
# 2025-12-01 11:04:18.407370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764587058.756166      44 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764587058.872053      44 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 2025-12-01 11:04:41.464305: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Namespace(c_dim=17, c2_dim=8, celeba_crop_size=178, rafd_crop_size=256, image_size=156, g_conv_dim=64, d_conv_dim=64, g_repeat_num=6, d_repeat_num=6, lambda_cls=1, lambda_rec=10, lambda_gp=10, dataset='CelebA', batch_size=1, num_iters=200000, num_iters_decay=100000, g_lr=0.0001, d_lr=0.0001, n_critic=5, beta1=0.5, beta2=0.999, resume_iters=None, selected_attrs=['Bald', 'Bangs', 'Black_Hair', 'Blond_Hair', 'Chubby', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'Male', 'Mouth_Slightly_Open', 'Mustache', 'No_Beard', 'Pale_Skin', 'Rosy_Cheeks', 'Smiling', 'Wearing_Lipstick'], test_iters=100000, num_workers=1, mode='test', use_tensorboard=True, celeba_image_dir='/kaggle/working/stargan/data/celeba/img', attr_path='/kaggle/working/stargan/data/celeba/1k_attr_face.txt', rafd_image_dir='data/RaFD/train', log_dir='stargan/logs', model_save_dir='/kaggle/working/stargan/stargan_celeba/models', sample_dir='stargan/samples', result_dir='/kaggle/working/stargan/stargan_celeba/results', log_step=10, sample_step=1000, model_save_step=10000, lr_update_step=1000)
# Finished preprocessing the CelebA dataset...
# Generator(
#   (main): Sequential(
#     (0): Conv2d(20, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (16): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (19): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (22): Tanh()
#   )
# )
# G
# The number of parameters: 8468160
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (conv1): Conv2d(2048, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv2): Conv2d(2048, 17, kernel_size=(2, 2), stride=(1, 1), bias=False)
# )
# D
# The number of parameters: 44860352
# Loading the trained models from step 100000...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/1-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/2-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/3-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/4-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/5-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/6-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/7-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/8-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/9-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/10-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/11-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/12-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/13-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/14-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/15-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/16-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/17-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/18-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/19-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/20-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/21-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/22-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/23-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/24-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/25-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/26-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/27-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/28-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/29-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/30-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/31-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/32-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/33-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/34-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/35-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/36-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/37-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/38-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/39-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/40-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/41-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/42-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/43-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/44-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/45-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/46-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/47-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/48-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/49-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/50-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/51-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/52-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/53-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/54-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/55-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/56-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/57-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/58-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/59-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/60-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/61-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/62-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/63-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/64-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/65-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/66-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/67-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/68-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/69-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/70-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/71-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/72-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/73-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/74-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/75-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/76-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/77-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/78-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/79-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/80-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/81-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/82-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/83-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/84-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/85-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/86-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/87-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/88-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/89-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/90-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/91-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/92-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/93-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/94-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/95-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/96-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/97-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/98-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/99-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/100-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/101-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/102-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/103-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/104-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/105-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/106-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/107-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/108-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/109-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/110-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/111-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/112-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/113-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/114-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/115-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/116-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/117-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/118-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/119-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/120-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/121-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/122-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/123-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/124-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/125-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/126-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/127-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/128-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/129-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/130-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/131-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/132-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/133-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/134-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/135-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/136-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/137-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/138-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/139-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/140-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/141-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/142-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/143-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/144-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/145-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/146-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/147-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/148-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/149-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/150-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/151-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/152-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/153-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/154-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/155-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/156-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/157-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/158-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/159-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/160-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/161-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/162-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/163-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/164-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/165-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/166-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/167-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/168-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/169-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/170-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/171-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/172-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/173-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/174-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/175-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/176-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/177-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/178-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/179-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/180-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/181-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/182-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/183-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/184-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/185-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/186-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/187-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/188-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/189-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/190-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/191-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/192-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/193-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/194-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/195-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/196-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/197-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/198-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/199-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/200-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/201-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/202-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/203-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/204-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/205-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/206-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/207-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/208-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/209-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/210-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/211-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/212-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/213-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/214-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/215-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/216-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/217-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/218-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/219-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/220-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/221-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/222-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/223-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/224-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/225-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/226-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/227-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/228-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/229-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/230-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/231-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/232-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/233-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/234-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/235-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/236-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/237-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/238-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/239-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/240-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/241-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/242-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/243-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/244-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/245-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/246-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/247-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/248-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/249-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/250-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/251-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/252-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/253-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/254-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/255-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/256-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/257-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/258-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/259-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/260-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/261-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/262-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/263-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/264-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/265-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/266-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/267-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/268-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/269-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/270-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/271-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/272-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/273-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/274-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/275-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/276-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/277-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/278-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/279-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/280-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/281-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/282-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/283-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/284-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/285-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/286-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/287-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/288-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/289-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/290-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/291-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/292-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/293-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/294-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/295-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/296-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/297-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/298-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/299-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/300-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/301-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/302-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/303-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/304-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/305-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/306-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/307-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/308-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/309-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/310-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/311-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/312-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/313-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/314-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/315-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/316-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/317-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/318-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/319-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/320-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/321-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/322-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/323-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/324-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/325-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/326-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/327-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/328-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/329-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/330-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/331-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/332-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/333-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/334-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/335-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/336-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/337-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/338-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/339-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/340-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/341-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/342-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/343-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/344-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/345-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/346-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/347-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/348-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/349-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/350-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/351-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/352-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/353-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/354-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/355-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/356-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/357-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/358-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/359-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/360-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/361-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/362-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/363-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/364-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/365-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/366-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/367-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/368-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/369-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/370-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/371-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/372-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/373-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/374-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/375-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/376-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/377-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/378-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/379-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/380-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/381-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/382-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/383-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/384-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/385-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/386-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/387-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/388-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/389-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/390-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/391-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/392-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/393-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/394-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/395-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/396-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/397-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/398-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/399-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/400-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/401-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/402-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/403-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/404-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/405-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/406-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/407-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/408-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/409-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/410-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/411-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/412-images.jpg...
# ...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/838-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/839-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/840-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/841-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/842-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/843-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/844-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/845-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/846-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/847-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/848-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/849-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/850-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/851-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/852-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/853-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/854-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/855-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/856-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/857-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/858-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/859-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/860-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/861-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/862-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/863-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/864-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/865-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/866-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/867-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/868-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/869-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/870-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/871-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/872-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/873-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/874-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/875-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/876-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/877-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/878-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/879-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/880-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/881-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/882-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/883-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/884-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/885-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/886-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/887-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/888-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/889-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/890-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/891-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/892-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/893-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/894-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/895-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/896-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/897-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/898-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/899-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/900-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/901-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/902-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/903-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/904-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/905-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/906-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/907-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/908-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/909-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/910-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/911-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/912-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/913-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/914-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/915-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/916-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/917-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/918-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/919-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/920-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/921-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/922-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/923-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/924-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/925-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/926-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/927-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/928-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/929-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/930-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/931-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/932-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/933-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/934-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/935-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/936-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/937-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/938-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/939-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/940-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/941-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/942-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/943-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/944-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/945-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/946-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/947-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/948-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/949-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/950-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/951-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/952-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/953-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/954-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/955-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/956-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/957-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/958-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/959-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/960-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/961-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/962-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/963-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/964-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/965-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/966-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/967-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/968-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/969-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/970-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/971-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/972-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/973-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/974-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/975-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/976-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/977-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/978-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/979-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/980-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/981-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/982-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/983-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/984-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/985-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/986-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/987-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/988-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/989-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/990-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/991-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/992-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/993-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/994-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/995-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/996-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/997-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/998-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/999-images.jpg...
# Saved real and fake images into /kaggle/working/stargan/stargan_celeba/results/1000-images.jpg...
# Test done in 5685.8s
# Evaluating SSIM/FID ...
# Eval done in 7437.6s | SSIM=0.7362 | FID=79.42
# Saved to /kaggle/working/stargan_eval_results_master.csv
